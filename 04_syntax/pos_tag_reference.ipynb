# %%
import pandas as pd

# Common POS tags found in this analysis
pos_reference = {
    "Tag": [
        "NN", "NNS", "NNP", "NNPS",
        "VB", "VBD", "VBG", "VBN", "VBP", "VBZ",
        "JJ", "JJR", "JJS",
        "RB", "RBR", "RBS",
        "DT", "IN", "PRP", "PRP$",
        "CC", "CD", "TO", "MD"
    ],
    "Meaning": [
        "Noun (singular)",
        "Noun (plural)",
        "Proper noun (singular)",
        "Proper noun (plural)",
        "Verb (base form)",
        "Verb (past tense)",
        "Verb (-ing form)",
        "Verb (past participle)",
        "Verb (non-3rd person singular)",
        "Verb (3rd person singular)",
        "Adjective",
        "Comparative adjective",
        "Superlative adjective",
        "Adverb",
        "Comparative adverb",
        "Superlative adverb",
        "Determiner",
        "Preposition / subordinating conjunction",
        "Personal pronoun",
        "Possessive pronoun",
        "Coordinating conjunction",
        "Cardinal number",
        "to",
        "Modal verb"
    ]
}

pd.DataFrame(pos_reference)
# Out:
#      Tag                                  Meaning
# 0     NN                          Noun (singular)
# 1    NNS                            Noun (plural)
# 2    NNP                   Proper noun (singular)
# 3   NNPS                     Proper noun (plural)
# 4     VB                         Verb (base form)
# 5    VBD                        Verb (past tense)
# 6    VBG                         Verb (-ing form)
# 7    VBN                   Verb (past participle)
# 8    VBP           Verb (non-3rd person singular)
# 9    VBZ               Verb (3rd person singular)
# 10    JJ                                Adjective
# 11   JJR                    Comparative adjective
# 12   JJS                    Superlative adjective
# 13    RB                                   Adverb
# 14   RBR                       Comparative adverb
# 15   RBS                       Superlative adverb
# 16    DT                               Determiner
# 17    IN  Preposition / subordinating conjunction
# 18   PRP                         Personal pronoun
# 19  PRP$                       Possessive pronoun
# 20    CC                 Coordinating conjunction
# 21    CD                          Cardinal number
# 22    TO                                       to
# 23    MD                               Modal verb
